# %% [markdown]
# <a href="https://colab.research.google.com/github/ahcamachod/2299-data-science-exploracion-y-analisis-de-datos/blob/main/data_science_ead.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data Science: Exploración y análisis de datos**

# %% [markdown]
# ## **Clase 1: Introducción**

# %% [markdown]
# ## **Clase 2: Explorando las películas**

# %% [markdown]
# ## **Clase 3: Otras Películas**

# %% [markdown]
# ## **Clase 4: Mejorando nuestra visualización**

# %% [markdown]
# ## Clase 5: **Comparar dos distribuciones visualmente o a través de medidas**
